# %% [markdown]
# # Multimodal loss exploration advantages
#
# All ensembles have the advantage of being able to explore and identify multiple ideal minimas, however, we are ideally suited to select the "best" minima.
#
# All we have to do is sample a bunch of neural networks and choose the seeds (z) that perform best on a hold-out validation set
