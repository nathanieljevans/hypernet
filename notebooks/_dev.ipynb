# %%
from GaNN.models.GaNN import GaNN
import torch 

# %load_ext autoreload
# %autoreload 2

# %%
x = torch.randn(10,2)
y =  torch.randn(10,2)


model = GaNN(x.size(1), y.size(1), hidden_channels=12, layers=2, gaussian_channels=10, width=10, norm='batch')
model(x, 2)
# Out:
# tensor([[[ 0.3998,  0.7867],
#          [ 0.0534,  0.7432],
#          [ 0.0842,  0.7151],
#          [-0.9644,  0.6310],
#          [-0.6308,  1.6673],
#          [ 0.0709,  0.7299],
#          [-0.6731,  0.1010],
#          [-0.1527,  0.9788],
#          [ 0.0526,  0.8223],
#          [-0.9082,  0.0927]],
#
#         [[-0.0637, -0.1220],
#          [ 0.0544, -0.6441],
#          [ 0.1524, -0.5952],
#          [ 0.3504,  0.2985],
#          [ 1.1677, -0.0188],
#          [-0.0646, -0.6833],
#          [-0.1449,  0.1825],
#          [ 0.5414, -0.2202],
#          [ 0.3299,  0.0842],
#          [-0.2199,  0.1278]]], grad_fn=<PermuteBackward0>)
