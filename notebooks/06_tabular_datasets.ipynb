# %%
import torch 
from matplotlib import pyplot as plt
import numpy as np
from GaNN.models.GaNN import GaNN
from GaNN.synth import generate
from GaNN.synth import utils 
from GaNN.train.run import run_sklearn_dataset

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Diabetes Dataset

# %%
train_kwargs = {'num_epochs' : 1000,
                    'nsamples' : 1 ,
                    'batch_size' : 250,
                    'lr' : 1e-4,
                    'loss_fn':'mse',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':50, 
                'layers':2, 
                'gaussian_channels':25, 
                'width':25}

ien_test_dict = run_sklearn_dataset('diabetes', 'ien', model_kwargs, train_kwargs)
ien_test_dict
# Out:
# progress: 999/1000 --> loss: 0.9003
# {'mse': 0.70239276, 'r2': 0.19443261623382568, 'nll': 0.4225790500640869}

# %%
train_kwargs = {'num_epochs' : 1000,
                    'nsamples' : 100 ,
                    'batch_size' : 250,
                    'lr' : 1e-4,
                    'loss_fn':'nll',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':50, 
                'layers':2, 
                'gaussian_channels':8, 
                'width':25}

ien_test_dict = run_sklearn_dataset('diabetes', 'ien', model_kwargs, train_kwargs)
ien_test_dict
# Out:
# progress: 999/1000 --> loss: -0.010
# {'mse': 0.45764396, 'r2': 0.47513264417648315, 'nll': 0.12671764194965363}

# %%
train_kwargs = {'num_epochs' : 250,
                    'nsamples' : 100 ,
                    'batch_size' : 32,
                    'lr' : 1e-3,
                    'loss_fn':'edl',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':50, 
                'layers':2, 
                'gaussian_channels':8, 
                'width':25}

ien_test_dict = run_sklearn_dataset('diabetes', 'ien', model_kwargs, train_kwargs)
ien_test_dict
# Out:
# progress: 249/250 --> loss: 0.223
# {'mse': 0.5571278, 'r2': 0.36103564500808716, 'nll': 0.8523041605949402}

# %%
train_kwargs = {'num_epochs' : 1000,
                    'batch_size' : 250,
                    'lr' : 1e-3,
                    'loss_fn':'mse',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':50, 
                'layers':2,
                'dropout':0.5}

ien_test_dict = run_sklearn_dataset('diabetes', 'mcdo', model_kwargs, train_kwargs)
ien_test_dict
# Out:
# progress: 999/1000 --> loss: 0.393
# {'mse': 0.4159055, 'r2': 0.523002028465271, 'nll': 1.2839552164077759}

# %%
train_kwargs = {'num_epochs' : 1000,
                    'batch_size' : 20,
                    'lr' : 1e-4,
                    'loss_fn':'mse',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':50, 
                'layers':2}

ien_test_dict = run_sklearn_dataset('diabetes', 'mcbn', model_kwargs, train_kwargs)
ien_test_dict
# Out:
# progress: 999/1000 --> loss: 0.143
# {'mse': 0.7042019, 'r2': 0.19235771894454956, 'nll': 352094.03125}

# %% [markdown]
# # California Dataset

# %%
train_kwargs = {'num_epochs' : 250,
                    'nsamples' : 100 ,
                    'batch_size' : 1014,
                    'lr' : 1e-3,
                    'loss_fn':'mse',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':50, 
                'layers':2, 
                'gaussian_channels':25, 
                'width':25}

ien_test_dict = run_sklearn_dataset('california', 'ien', model_kwargs, train_kwargs)
ien_test_dict
# Out:
# progress: 249/250 --> loss: 0.194
# {'mse': 0.19755107, 'r2': 0.798473596572876, 'nll': 12.945100784301758}

# %%
train_kwargs = {'num_epochs' : 500,
                    'nsamples' : 100 ,
                    'batch_size' : 1024,
                    'lr' : 1e-3,
                    'loss_fn':'nll',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':50, 
                'layers':2, 
                'gaussian_channels':8, 
                'width':25}

ien_test_dict = run_sklearn_dataset('california', 'ien', model_kwargs, train_kwargs)
ien_test_dict
# Out:
# progress: 499/500 --> loss: -0.993
# {'mse': 0.18763414, 'r2': 0.8085901141166687, 'nll': -0.4540756046772003}

# %%
train_kwargs = {'num_epochs' : 500,
                    'nsamples' : 100 ,
                    'batch_size' : 1024,
                    'lr' : 1e-3,
                    'loss_fn':'edl',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':50, 
                'layers':2, 
                'gaussian_channels':8, 
                'width':25}

ien_test_dict = run_sklearn_dataset('california', 'ien', model_kwargs, train_kwargs)
ien_test_dict
# Out:
# progress: 154/500 --> loss: 0.398
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 13
#       1 train_kwargs = {'num_epochs' : 500,
#       2                     'nsamples' : 100 ,
#       3                     'batch_size' : 1024,
#       4                     'lr' : 1e-3,
#       5                     'loss_fn':'edl',
#       6                     'use_cuda':True}
#       8 model_kwargs = {'hidden_channels':50,
#       9                 'layers':2,
#      10                 'gaussian_channels':8,
#      11                 'width':25}
# ---> 13 ien_test_dict = run_sklearn_dataset('california', 'ien', model_kwargs, train_kwargs)
#      14 ien_test_dict
#
# File ~/local/GaNN/GaNN/train/run.py:60, in run_sklearn_dataset(dataset_name, model_name, model_kwargs, train_kwargs, seed, task)
#      57 y_test_tensor = torch.tensor(y_test).unsqueeze(1)
# ...

# %%
train_kwargs = {'num_epochs' : 500,
                    'batch_size' : 1024,
                    'lr' : 1e-3,
                    'loss_fn':'mse',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':50, 
                'layers':2,
                'dropout':0.5}

ien_test_dict = run_sklearn_dataset('california', 'mcdo', model_kwargs, train_kwargs)
ien_test_dict
# Out:
# progress: 499/500 --> loss: 0.279
# {'mse': 0.22899878, 'r2': 0.7663931250572205, 'nll': 0.6866901516914368}

# %%
train_kwargs = {'num_epochs' : 100,
                    'batch_size' : 64,
                    'lr' : 1e-3,
                    'loss_fn':'mse',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':50, 
                'layers':2}

ien_test_dict = run_sklearn_dataset('california', 'mcbn', model_kwargs, train_kwargs)
ien_test_dict
# Out:
# progress: 26/100 --> loss: 0.223
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 10
#       1 train_kwargs = {'num_epochs' : 100,
#       2                     'batch_size' : 64,
#       3                     'lr' : 1e-3,
#       4                     'loss_fn':'mse',
#       5                     'use_cuda':True}
#       7 model_kwargs = {'hidden_channels':50,
#       8                 'layers':2}
# ---> 10 ien_test_dict = run_sklearn_dataset('california', 'mcbn', model_kwargs, train_kwargs)
#      11 ien_test_dict
#
# File ~/local/GaNN/GaNN/train/run.py:86, in run_sklearn_dataset(dataset_name, model_name, model_kwargs, train_kwargs, seed, task)
#      83         y_true = y_test_tensor
#      85 elif model_name == 'mcbn':
# ---> 86     model, losses = train_mcbn(X_train_tensor, y_train_tensor, model_kwargs=model_kwargs, **train_kwargs)
# ...

# %% [markdown]
# # MNIST

# %%
train_kwargs = {'num_epochs' : 50,
                    'nsamples' : 100 ,
                    'batch_size' : 256,
                    'lr' : 1e-4,
                    'loss_fn':'ce',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':200, 
                'layers':2, 
                'gaussian_channels':25, 
                'width':25,
                'norm':'batch'}

ien_test_dict = run_sklearn_dataset('mnist', 'ien', model_kwargs, train_kwargs, task='classification')
ien_test_dict
# Out:
# progress: 49/50 --> loss: 0.009
# {'ce': 0.08246320486068726,
#  'acc': 0.9835000038146973,
#  'ece': 0.011639829725027084}

# %%
train_kwargs = {'num_epochs' : 100,
                    'batch_size' : 1024,
                    'lr' : 1e-3,
                    'loss_fn':'ce',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':200, 
                'layers':2,
                'dropout':0.5,
                'norm':'batch'}

ien_test_dict = run_sklearn_dataset('mnist', 'mcdo', model_kwargs, train_kwargs, task='classification')
ien_test_dict
# Out:
# progress: 99/100 --> loss: 0.036
# {'ce': 0.06874165683984756,
#  'acc': 0.9818999767303467,
#  'ece': 0.008276374079287052}

# %%
train_kwargs = {'num_epochs' : 100,
                    'batch_size' : 1024,
                    'lr' : 1e-3,
                    'loss_fn':'ce',
                    'use_cuda':True}
    
model_kwargs = {'hidden_channels':50, 
                'layers':2}

ien_test_dict = run_sklearn_dataset('mnist', 'mcbn', model_kwargs, train_kwargs, task='classification')
ien_test_dict
# Out:
# progress: 99/100 --> loss: 0.000
# {'ce': 0.13201887905597687,
#  'acc': 0.973800003528595,
#  'ece': 0.018339496105909348}
